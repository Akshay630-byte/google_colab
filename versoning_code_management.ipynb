# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay630-byte/google_colab/blob/upgrad/versoning_code_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
numpy.__version__

#!pip install numpy==2.5
# Out:
# '2.5.0'
