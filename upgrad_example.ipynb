# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay630-byte/google_colab/blob/upgrad/upgrad_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python

# %% [markdown]
# ## Addition function

# %%
print ('shree swami samarth')
def temp_add(a,b):
  c=a+b
  return(c)
# Out:
# shree swami samarth

# %% [markdown]
# ## main function

# %%
if __name__=='__main__':
  z=temp_add(7,3)
  print('Result of operation',z)
# Out:
# Result of operation 10
